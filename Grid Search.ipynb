# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras
from keras import layers
from tensorflow import random
from scikeras.wrappers import KerasClassifier
import sklearn
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential

# %%
seed_value = 42
np.random.seed(seed_value)
random.set_seed(seed_value)

# %%
training_data = pd.read_csv('./as1-bank-1.csv')

# %%
training_data.replace("yes", 1, inplace=True)
training_data.replace("no", 0, inplace=True)

# %%
training_y = training_data.pop('y')
training_x = training_data

# %%
selected_features = ['age', 'marital', 'education', 'balance', 'housing', 'loan', 'duration', 'campaign', 'pdays' , 'poutcome']
training_x = training_x[selected_features]

# %%
arr_train_x = training_x.to_numpy()
arr_train_y = training_y.to_numpy()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(arr_train_x)

# %%
from sklearn.model_selection import train_test_split

# Train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(
    X_train_scaled, arr_train_y, test_size=0.3, random_state=seed_value)

# %%
# Use scikit-learn to grid search the number of neurons 
# Function to create model, required for KerasClassifier
def create_model(neurons):
 # create model
 model = Sequential()
    
 model.add(layers.InputLayer(input_shape=(10))) #10 input columns

 model.add(layers.Dense(neurons, activation="relu"))
 
 model.add(layers.Dense(1, activation='sigmoid'))
           
 # Compile model
 model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
 return model

# create model
model = KerasClassifier(model=create_model, epochs=60, verbose=0)
# define the grid search parameters

neurons = [4, 16, 32, 64, 128, 256, 512]

param_grid = dict(model__neurons=neurons)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X_train, Y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.832394 using {'model__neurons': 128}
# 0.820916 (0.008078) with: {'model__neurons': 4}
# 0.828203 (0.003867) with: {'model__neurons': 16}
# 0.830572 (0.008565) with: {'model__neurons': 32}
# 0.826017 (0.006549) with: {'model__neurons': 64}
# 0.832394 (0.006912) with: {'model__neurons': 128}
# 0.831846 (0.003814) with: {'model__neurons': 256}
# 0.830390 (0.007020) with: {'model__neurons': 512}

# %%
# Use scikit-learn to grid search the number of neurons & Hidden layers
# Function to create model, required for KerasClassifier
def create_model(neurons, hidden_layers):
 # create model
 model = Sequential()
    
 model.add(layers.InputLayer(input_shape=(10))) #10 input columns

 for i in range(hidden_layers):
        model.add(layers.Dense(neurons, activation="relu"))
 
 model.add(layers.Dense(1, activation='sigmoid'))
           
 # Compile model
 model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
 return model

# create model
model = KerasClassifier(model=create_model, epochs=60, verbose=0)
# define the grid search parameters
neurons = [4, 16, 32, 64, 128, 256, 514]
hidden_layers = [1,2,3,4,5,6]
param_grid = dict(model__neurons=neurons, model__hidden_layers=hidden_layers)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X_train, Y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.836948 using {'model__hidden_layers': 2, 'model__neurons': 514}
# 0.804519 (0.004097) with: {'model__hidden_layers': 1, 'model__neurons': 4}
# 0.824195 (0.007144) with: {'model__hidden_layers': 1, 'model__neurons': 16}
# 0.828568 (0.006911) with: {'model__hidden_layers': 1, 'model__neurons': 32}
# 0.826199 (0.007419) with: {'model__hidden_layers': 1, 'model__neurons': 64}
# 0.830755 (0.009785) with: {'model__hidden_layers': 1, 'model__neurons': 128}
# 0.830936 (0.007553) with: {'model__hidden_layers': 1, 'model__neurons': 256}
# 0.830936 (0.006148) with: {'model__hidden_layers': 1, 'model__neurons': 514}
# 0.800328 (0.003714) with: {'model__hidden_layers': 2, 'model__neurons': 4}
# 0.826926 (0.005086) with: {'model__hidden_layers': 2, 'model__neurons': 16}
# 0.828933 (0.008849) with: {'model__hidden_layers': 2, 'model__neurons': 32}
# 0.832393 (0.009036) with: {'model__hidden_layers': 2, 'model__neurons': 64}
# 0.836037 (0.004497) with: {'model__hidden_layers': 2, 'model__neurons': 128}
# 0.835854 (0.008281) with: {'model__hidden_layers': 2, 'model__neurons': 256}
# 0.836948 (0.007828) with: {'model__hidden_layers': 2, 'model__neurons': 514}
# 0.825469 (0.006369) with: {'model__hidden_layers': 3, 'model__neurons': 4}
# 0.831118 (0.006578) with: {'model__hidden_layers': 3, 'model__neurons': 16}
# 0.832393 (0.005138) with: {'model__hidden_layers': 3, 'model__neurons': 32}
# 0.834580 (0.007801) with: {'model__hidden_layers': 3, 'model__neurons': 64}
# 0.836037 (0.010476) with: {'model__hidden_layers': 3, 'model__neurons': 128}
# 0.836037 (0.005974) with: {'model__hidden_layers': 3, 'model__neurons': 256}
# 0.836037 (0.008746) with: {'model__hidden_layers': 3, 'model__neurons': 514}
# 0.801969 (0.010291) with: {'model__hidden_layers': 4, 'model__neurons': 4}
# 0.832028 (0.002496) with: {'model__hidden_layers': 4, 'model__neurons': 16}
# 0.827656 (0.004541) with: {'model__hidden_layers': 4, 'model__neurons': 32}
# 0.836766 (0.007767) with: {'model__hidden_layers': 4, 'model__neurons': 64}
# 0.831483 (0.009559) with: {'model__hidden_layers': 4, 'model__neurons': 128}
# 0.834032 (0.006053) with: {'model__hidden_layers': 4, 'model__neurons': 256}
# 0.830935 (0.002694) with: {'model__hidden_layers': 4, 'model__neurons': 514}
# 0.809074 (0.005847) with: {'model__hidden_layers': 5, 'model__neurons': 4}
# 0.818909 (0.005489) with: {'model__hidden_layers': 5, 'model__neurons': 16}
# 0.831300 (0.004022) with: {'model__hidden_layers': 5, 'model__neurons': 32}
# 0.829660 (0.007786) with: {'model__hidden_layers': 5, 'model__neurons': 64}
# 0.827837 (0.002716) with: {'model__hidden_layers': 5, 'model__neurons': 128}
# 0.834760 (0.006062) with: {'model__hidden_layers': 5, 'model__neurons': 256}
# 0.820368 (0.008702) with: {'model__hidden_layers': 5, 'model__neurons': 514}
# 0.783747 (0.014584) with: {'model__hidden_layers': 6, 'model__neurons': 4}
# 0.830388 (0.005024) with: {'model__hidden_layers': 6, 'model__neurons': 16}
# 0.833667 (0.003793) with: {'model__hidden_layers': 6, 'model__neurons': 32}
# 0.826926 (0.001406) with: {'model__hidden_layers': 6, 'model__neurons': 64}
# 0.819274 (0.009294) with: {'model__hidden_layers': 6, 'model__neurons': 128}
# 0.822191 (0.012318) with: {'model__hidden_layers': 6, 'model__neurons': 256}
# 0.818365 (0.004736) with: {'model__hidden_layers': 6, 'model__neurons': 514}

# %%
# Use scikit-learn to grid search the number of neurons & Hidden layers
# Function to create model, required for KerasClassifier
def create_model(hidden_layers):
 # create model
 model = Sequential()
    
 model.add(layers.InputLayer(input_shape=(10))) #10 input columns

 for i, neurons in enumerate(hidden_layers):
            model.add(layers.Dense(neurons, activation="relu"))
        
 model.add(layers.Dense(1, activation='sigmoid'))
           
 # Compile model
 model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
 return model

# create model
model = KerasClassifier(model=create_model, epochs=60, verbose=0)
# define the grid search parameters
hidden_layers = []
neurons1 = [4, 16, 32, 64, 128, 256, 512]
neurons2 = [4, 16, 32, 64, 128, 256, 512]

for i in (neurons1):
    for j in (neurons2):
        if(i != j):
            hidden_layers.append([i, j])

param_grid = dict(model__hidden_layers=hidden_layers)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X_train, Y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.839863 using {'model__hidden_layers': [256, 512]}
# 0.819276 (0.003541) with: {'model__hidden_layers': [4, 16]}
# 0.830935 (0.007106) with: {'model__hidden_layers': [4, 32]}
# 0.802154 (0.020713) with: {'model__hidden_layers': [4, 64]}
# 0.812352 (0.001118) with: {'model__hidden_layers': [4, 128]}
# 0.804522 (0.014130) with: {'model__hidden_layers': [4, 256]}
# 0.824379 (0.009909) with: {'model__hidden_layers': [4, 512]}
# 0.824924 (0.006018) with: {'model__hidden_layers': [16, 4]}
# 0.830573 (0.009458) with: {'model__hidden_layers': [16, 32]}
# 0.830572 (0.006892) with: {'model__hidden_layers': [16, 64]}
# 0.825470 (0.009522) with: {'model__hidden_layers': [16, 128]}
# 0.829660 (0.009516) with: {'model__hidden_layers': [16, 256]}
# 0.824743 (0.009428) with: {'model__hidden_layers': [16, 512]}
# 0.827837 (0.006484) with: {'model__hidden_layers': [32, 4]}
# 0.835309 (0.010304) with: {'model__hidden_layers': [32, 16]}
# 0.834762 (0.007655) with: {'model__hidden_layers': [32, 64]}
# 0.830571 (0.007754) with: {'model__hidden_layers': [32, 128]}
# 0.829114 (0.007460) with: {'model__hidden_layers': [32, 256]}
# 0.832393 (0.009780) with: {'model__hidden_layers': [32, 512]}
# 0.832575 (0.008011) with: {'model__hidden_layers': [64, 4]}
# 0.834396 (0.010262) with: {'model__hidden_layers': [64, 16]}
# 0.833850 (0.007601) with: {'model__hidden_layers': [64, 32]}
# 0.832941 (0.011556) with: {'model__hidden_layers': [64, 128]}
# 0.835126 (0.009924) with: {'model__hidden_layers': [64, 256]}
# 0.830389 (0.007655) with: {'model__hidden_layers': [64, 512]}
# 0.832029 (0.006882) with: {'model__hidden_layers': [128, 4]}
# 0.837312 (0.008326) with: {'model__hidden_layers': [128, 16]}
# 0.835490 (0.008494) with: {'model__hidden_layers': [128, 32]}
# 0.833122 (0.006975) with: {'model__hidden_layers': [128, 64]}
# 0.832028 (0.008502) with: {'model__hidden_layers': [128, 256]}
# 0.836402 (0.008271) with: {'model__hidden_layers': [128, 512]}
# 0.836037 (0.007326) with: {'model__hidden_layers': [256, 4]}
# 0.832758 (0.010368) with: {'model__hidden_layers': [256, 16]}
# 0.837312 (0.007984) with: {'model__hidden_layers': [256, 32]}
# 0.838405 (0.008275) with: {'model__hidden_layers': [256, 64]}
# 0.836219 (0.008511) with: {'model__hidden_layers': [256, 128]}
# 0.839863 (0.008524) with: {'model__hidden_layers': [256, 512]}
# 0.833851 (0.007710) with: {'model__hidden_layers': [512, 4]}
# 0.835126 (0.009036) with: {'model__hidden_layers': [512, 16]}
# 0.837312 (0.008633) with: {'model__hidden_layers': [512, 32]}
# 0.838588 (0.006785) with: {'model__hidden_layers': [512, 64]}
# 0.838587 (0.006551) with: {'model__hidden_layers': [512, 128]}
# 0.837859 (0.008943) with: {'model__hidden_layers': [512, 256]}

# %%
# Use scikit-learn to grid search the number of neurons & Hidden layers
# Function to create model, required for KerasClassifier
def create_model(hidden_layers):
 # create model
 model = Sequential()
    
 model.add(layers.InputLayer(input_shape=(10))) #10 input columns

 for i, neurons in enumerate(hidden_layers):
            model.add(layers.Dense(neurons, activation="relu"))
        
 model.add(layers.Dense(1, activation='sigmoid'))
           
 # Compile model
 model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
 return model

# create model
model = KerasClassifier(model=create_model, epochs=60, verbose=0)
# define the grid search parameters
hidden_layers = []
neurons1 = [4, 16, 32, 64, 128, 256, 512]
neurons2 = [4, 16, 32, 64, 128, 256, 512]
neurons3 = [4, 16, 32, 64, 128, 256, 512]

for i in (neurons1):
    for j in (neurons2):
        for k in (neurons3):
            if (i != j & j!= k):
                hidden_layers.append([i, j, k])

param_grid = dict(model__hidden_layers=hidden_layers)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X_train, Y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# C:\Users\Swift 3\anaconda3\Lib\site-packages\joblib\externals\loky\process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best: 0.839134 using {'model__hidden_layers': [128, 256, 32]}
# 0.801421 (0.001006) with: {'model__hidden_layers': [4, 16, 4]}
# 0.815814 (0.015187) with: {'model__hidden_layers': [4, 16, 32]}
# 0.822917 (0.007224) with: {'model__hidden_layers': [4, 16, 64]}
# 0.811809 (0.015319) with: {'model__hidden_layers': [4, 16, 128]}
# 0.814354 (0.007911) with: {'model__hidden_layers': [4, 16, 256]}
# 0.817454 (0.004362) with: {'model__hidden_layers': [4, 16, 512]}
# 0.806521 (0.008280) with: {'model__hidden_layers': [4, 32, 4]}
# 0.819459 (0.014535) with: {'model__hidden_layers': [4, 32, 16]}
# 0.813627 (0.002820) with: {'model__hidden_layers': [4, 32, 64]}
# 0.816546 (0.020833) with: {'model__hidden_layers': [4, 32, 128]}
# 0.800874 (0.006200) with: {'model__hidden_layers': [4, 32, 256]}
# 0.823466 (0.009664) with: {'model__hidden_layers': [4, 32, 512]}
# 0.824744 (0.012863) with: {'model__hidden_layers': [4, 64, 4]}
# 0.811444 (0.013177) with: {'model__hidden_layers': [4, 64, 16]}
# 0.820187 (0.012012) with: {'model__hidden_layers': [4, 64, 32]}
# 0.825836 (0.011117) with: {'model__hidden_layers': [4, 64, 128]}
# 0.809255 (0.004080) with: {'model__hidden_layers': [4, 64, 256]}
# 0.815084 (0.014020) with: {'model__hidden_layers': [4, 64, 512]}
# 0.804884 (0.007585) with: {'model__hidden_layers': [4, 128, 4]}
# 0.815631 (0.002901) with: {'model__hidden_layers': [4, 128, 16]}
# 0.806886 (0.003087) with: {'model__hidden_layers': [4, 128, 32]}
# 0.816728 (0.016035) with: {'model__hidden_layers': [4, 128, 64]}
# 0.818728 (0.009594) with: {'model__hidden_layers': [4, 128, 256]}
# 0.818730 (0.013259) with: {'model__hidden_layers': [4, 128, 512]}
# 0.824014 (0.015319) with: {'model__hidden_layers': [4, 256, 4]}
# 0.815452 (0.013160) with: {'model__hidden_layers': [4, 256, 16]}
# 0.808708 (0.003230) with: {'model__hidden_layers': [4, 256, 32]}
# 0.828747 (0.006533) with: {'model__hidden_layers': [4, 256, 64]}
# 0.807250 (0.003205) with: {'model__hidden_layers': [4, 256, 128]}
# 0.822006 (0.005658) with: {'model__hidden_layers': [4, 256, 512]}
# 0.821642 (0.009049) with: {'model__hidden_layers': [4, 512, 4]}
# 0.811808 (0.008656) with: {'model__hidden_layers': [4, 512, 16]}
# 0.803790 (0.004052) with: {'model__hidden_layers': [4, 512, 32]}
# 0.809620 (0.005318) with: {'model__hidden_layers': [4, 512, 64]}
# 0.811990 (0.011181) with: {'model__hidden_layers': [4, 512, 128]}
# 0.810165 (0.014677) with: {'model__hidden_layers': [4, 512, 256]}
# 0.824923 (0.002789) with: {'model__hidden_layers': [16, 4, 16]}
# 0.819278 (0.014091) with: {'model__hidden_layers': [16, 4, 32]}
# 0.820552 (0.008190) with: {'model__hidden_layers': [16, 4, 64]}
# 0.828568 (0.007652) with: {'model__hidden_layers': [16, 4, 128]}
# 0.831299 (0.011602) with: {'model__hidden_layers': [16, 4, 256]}
# 0.832394 (0.011525) with: {'model__hidden_layers': [16, 4, 512]}
# 0.828931 (0.005005) with: {'model__hidden_layers': [16, 32, 4]}
# 0.829296 (0.008834) with: {'model__hidden_layers': [16, 32, 16]}
# 0.835127 (0.009666) with: {'model__hidden_layers': [16, 32, 64]}
# 0.832394 (0.008064) with: {'model__hidden_layers': [16, 32, 128]}
# 0.830207 (0.007156) with: {'model__hidden_layers': [16, 32, 256]}
# 0.831119 (0.009905) with: {'model__hidden_layers': [16, 32, 512]}
# 0.824741 (0.003979) with: {'model__hidden_layers': [16, 64, 4]}
# 0.830025 (0.004218) with: {'model__hidden_layers': [16, 64, 16]}
# 0.827108 (0.007112) with: {'model__hidden_layers': [16, 64, 32]}
# 0.826380 (0.008869) with: {'model__hidden_layers': [16, 64, 128]}
# 0.828383 (0.006224) with: {'model__hidden_layers': [16, 64, 256]}
# 0.830389 (0.008845) with: {'model__hidden_layers': [16, 64, 512]}
# 0.831847 (0.008832) with: {'model__hidden_layers': [16, 128, 4]}
# 0.825835 (0.007332) with: {'model__hidden_layers': [16, 128, 16]}
# 0.831847 (0.007555) with: {'model__hidden_layers': [16, 128, 32]}
# 0.831300 (0.006046) with: {'model__hidden_layers': [16, 128, 64]}
# 0.832940 (0.004897) with: {'model__hidden_layers': [16, 128, 256]}
# 0.829477 (0.009504) with: {'model__hidden_layers': [16, 128, 512]}
# 0.825102 (0.012089) with: {'model__hidden_layers': [16, 256, 4]}
# 0.828203 (0.008489) with: {'model__hidden_layers': [16, 256, 16]}
# 0.838953 (0.016776) with: {'model__hidden_layers': [16, 256, 32]}
# 0.830208 (0.009750) with: {'model__hidden_layers': [16, 256, 64]}
# 0.828021 (0.006211) with: {'model__hidden_layers': [16, 256, 128]}
# 0.825470 (0.009898) with: {'model__hidden_layers': [16, 256, 512]}
# 0.832575 (0.006653) with: {'model__hidden_layers': [16, 512, 4]}
# 0.832940 (0.007840) with: {'model__hidden_layers': [16, 512, 16]}
# 0.834396 (0.005133) with: {'model__hidden_layers': [16, 512, 32]}
# 0.830754 (0.006468) with: {'model__hidden_layers': [16, 512, 64]}
# 0.835672 (0.005524) with: {'model__hidden_layers': [16, 512, 128]}
# 0.834579 (0.007227) with: {'model__hidden_layers': [16, 512, 256]}
# 0.826379 (0.005690) with: {'model__hidden_layers': [32, 4, 16]}
# 0.829661 (0.009004) with: {'model__hidden_layers': [32, 4, 32]}
# 0.826381 (0.009830) with: {'model__hidden_layers': [32, 4, 64]}
# 0.827108 (0.005899) with: {'model__hidden_layers': [32, 4, 128]}
# 0.828931 (0.000752) with: {'model__hidden_layers': [32, 4, 256]}
# 0.828203 (0.005788) with: {'model__hidden_layers': [32, 4, 512]}
# 0.828203 (0.003807) with: {'model__hidden_layers': [32, 16, 4]}
# 0.834215 (0.007204) with: {'model__hidden_layers': [32, 16, 32]}
# 0.834943 (0.008778) with: {'model__hidden_layers': [32, 16, 64]}
# 0.834944 (0.007996) with: {'model__hidden_layers': [32, 16, 128]}
# 0.834034 (0.008893) with: {'model__hidden_layers': [32, 16, 256]}
# 0.830754 (0.009768) with: {'model__hidden_layers': [32, 16, 512]}
# 0.833122 (0.004948) with: {'model__hidden_layers': [32, 64, 4]}
# 0.831119 (0.009465) with: {'model__hidden_layers': [32, 64, 16]}
# 0.833303 (0.003374) with: {'model__hidden_layers': [32, 64, 32]}
# 0.834033 (0.005966) with: {'model__hidden_layers': [32, 64, 128]}
# 0.836583 (0.005410) with: {'model__hidden_layers': [32, 64, 256]}
# 0.832758 (0.008882) with: {'model__hidden_layers': [32, 64, 512]}
# 0.837676 (0.006181) with: {'model__hidden_layers': [32, 128, 4]}
# 0.829843 (0.008750) with: {'model__hidden_layers': [32, 128, 16]}
# 0.834214 (0.006084) with: {'model__hidden_layers': [32, 128, 32]}
# 0.832939 (0.007051) with: {'model__hidden_layers': [32, 128, 64]}
# 0.834762 (0.008582) with: {'model__hidden_layers': [32, 128, 256]}
# 0.831119 (0.011145) with: {'model__hidden_layers': [32, 128, 512]}
# 0.832211 (0.009299) with: {'model__hidden_layers': [32, 256, 4]}
# 0.832211 (0.007421) with: {'model__hidden_layers': [32, 256, 16]}
# 0.830389 (0.008834) with: {'model__hidden_layers': [32, 256, 32]}
# 0.834943 (0.008924) with: {'model__hidden_layers': [32, 256, 64]}
# 0.832211 (0.007829) with: {'model__hidden_layers': [32, 256, 128]}
# 0.832939 (0.008336) with: {'model__hidden_layers': [32, 256, 512]}
# 0.829842 (0.004739) with: {'model__hidden_layers': [32, 512, 4]}
# 0.833305 (0.011666) with: {'model__hidden_layers': [32, 512, 16]}
# 0.831846 (0.005622) with: {'model__hidden_layers': [32, 512, 32]}
# 0.834942 (0.004676) with: {'model__hidden_layers': [32, 512, 64]}
# 0.832029 (0.008353) with: {'model__hidden_layers': [32, 512, 128]}
# 0.832758 (0.006534) with: {'model__hidden_layers': [32, 512, 256]}
# 0.829660 (0.004751) with: {'model__hidden_layers': [64, 4, 16]}
# 0.836765 (0.005977) with: {'model__hidden_layers': [64, 4, 32]}
# 0.836037 (0.005378) with: {'model__hidden_layers': [64, 4, 64]}
# 0.834215 (0.006234) with: {'model__hidden_layers': [64, 4, 128]}
# 0.830935 (0.000239) with: {'model__hidden_layers': [64, 4, 256]}
# 0.831664 (0.004796) with: {'model__hidden_layers': [64, 4, 512]}
# 0.832939 (0.004022) with: {'model__hidden_layers': [64, 16, 4]}
# 0.834032 (0.005562) with: {'model__hidden_layers': [64, 16, 32]}
# 0.836037 (0.010111) with: {'model__hidden_layers': [64, 16, 64]}
# 0.832576 (0.005989) with: {'model__hidden_layers': [64, 16, 128]}
# 0.831118 (0.007103) with: {'model__hidden_layers': [64, 16, 256]}
# 0.837130 (0.006533) with: {'model__hidden_layers': [64, 16, 512]}
# 0.836220 (0.009924) with: {'model__hidden_layers': [64, 32, 4]}
# 0.831665 (0.009292) with: {'model__hidden_layers': [64, 32, 16]}
# 0.835855 (0.006654) with: {'model__hidden_layers': [64, 32, 64]}
# 0.834944 (0.007148) with: {'model__hidden_layers': [64, 32, 128]}
# 0.834762 (0.007402) with: {'model__hidden_layers': [64, 32, 256]}
# 0.832758 (0.008586) with: {'model__hidden_layers': [64, 32, 512]}
# 0.833669 (0.008375) with: {'model__hidden_layers': [64, 128, 4]}
# 0.832939 (0.003609) with: {'model__hidden_layers': [64, 128, 16]}
# 0.832757 (0.007354) with: {'model__hidden_layers': [64, 128, 32]}
# 0.834579 (0.007465) with: {'model__hidden_layers': [64, 128, 64]}
# 0.836218 (0.006178) with: {'model__hidden_layers': [64, 128, 256]}
# 0.837130 (0.010534) with: {'model__hidden_layers': [64, 128, 512]}
# 0.835307 (0.004632) with: {'model__hidden_layers': [64, 256, 4]}
# 0.836948 (0.009127) with: {'model__hidden_layers': [64, 256, 16]}
# 0.834944 (0.008098) with: {'model__hidden_layers': [64, 256, 32]}
# 0.833851 (0.008166) with: {'model__hidden_layers': [64, 256, 64]}
# 0.834214 (0.005497) with: {'model__hidden_layers': [64, 256, 128]}
# 0.833304 (0.008778) with: {'model__hidden_layers': [64, 256, 512]}
# 0.834761 (0.007849) with: {'model__hidden_layers': [64, 512, 4]}
# 0.832210 (0.008171) with: {'model__hidden_layers': [64, 512, 16]}
# 0.837312 (0.010179) with: {'model__hidden_layers': [64, 512, 32]}
# 0.835856 (0.008778) with: {'model__hidden_layers': [64, 512, 64]}
# 0.833122 (0.007731) with: {'model__hidden_layers': [64, 512, 128]}
# 0.836765 (0.004797) with: {'model__hidden_layers': [64, 512, 256]}
# 0.831117 (0.008777) with: {'model__hidden_layers': [128, 4, 16]}
# 0.833121 (0.001119) with: {'model__hidden_layers': [128, 4, 32]}
# 0.832029 (0.009519) with: {'model__hidden_layers': [128, 4, 64]}
# 0.832757 (0.003778) with: {'model__hidden_layers': [128, 4, 128]}
# 0.836219 (0.004898) with: {'model__hidden_layers': [128, 4, 256]}
# 0.835672 (0.004797) with: {'model__hidden_layers': [128, 4, 512]}
# 0.837130 (0.007723) with: {'model__hidden_layers': [128, 16, 4]}
# 0.834762 (0.008155) with: {'model__hidden_layers': [128, 16, 32]}
# 0.836948 (0.006059) with: {'model__hidden_layers': [128, 16, 64]}
# 0.832576 (0.007123) with: {'model__hidden_layers': [128, 16, 128]}
# 0.836401 (0.002652) with: {'model__hidden_layers': [128, 16, 256]}
# 0.833850 (0.007829) with: {'model__hidden_layers': [128, 16, 512]}
# 0.829479 (0.012119) with: {'model__hidden_layers': [128, 32, 4]}
# 0.833668 (0.007208) with: {'model__hidden_layers': [128, 32, 16]}
# 0.834579 (0.007499) with: {'model__hidden_layers': [128, 32, 64]}
# 0.835125 (0.005924) with: {'model__hidden_layers': [128, 32, 128]}
# 0.835855 (0.008738) with: {'model__hidden_layers': [128, 32, 256]}
# 0.835307 (0.004931) with: {'model__hidden_layers': [128, 32, 512]}
# 0.835127 (0.012926) with: {'model__hidden_layers': [128, 64, 4]}
# 0.835308 (0.006437) with: {'model__hidden_layers': [128, 64, 16]}
# 0.836219 (0.004697) with: {'model__hidden_layers': [128, 64, 32]}
# 0.833122 (0.006842) with: {'model__hidden_layers': [128, 64, 128]}
# 0.833852 (0.012535) with: {'model__hidden_layers': [128, 64, 256]}
# 0.835673 (0.009394) with: {'model__hidden_layers': [128, 64, 512]}
# 0.833852 (0.010788) with: {'model__hidden_layers': [128, 256, 4]}
# 0.833669 (0.008070) with: {'model__hidden_layers': [128, 256, 16]}
# 0.839134 (0.008103) with: {'model__hidden_layers': [128, 256, 32]}
# 0.835490 (0.006996) with: {'model__hidden_layers': [128, 256, 64]}
# 0.834580 (0.008784) with: {'model__hidden_layers': [128, 256, 128]}
# 0.835854 (0.004949) with: {'model__hidden_layers': [128, 256, 512]}
# 0.835672 (0.007841) with: {'model__hidden_layers': [128, 512, 4]}
# 0.838769 (0.004288) with: {'model__hidden_layers': [128, 512, 16]}
# 0.834033 (0.008685) with: {'model__hidden_layers': [128, 512, 32]}
# 0.833851 (0.010799) with: {'model__hidden_layers': [128, 512, 64]}
# 0.831847 (0.010156) with: {'model__hidden_layers': [128, 512, 128]}
# 0.834215 (0.007204) with: {'model__hidden_layers': [128, 512, 256]}
# 0.836948 (0.006809) with: {'model__hidden_layers': [256, 4, 16]}
# 0.834580 (0.006882) with: {'model__hidden_layers': [256, 4, 32]}
# 0.834579 (0.006062) with: {'model__hidden_layers': [256, 4, 64]}
# 0.834761 (0.004948) with: {'model__hidden_layers': [256, 4, 128]}
# 0.830207 (0.006024) with: {'model__hidden_layers': [256, 4, 256]}
# 0.834942 (0.006596) with: {'model__hidden_layers': [256, 4, 512]}
# 0.836037 (0.007711) with: {'model__hidden_layers': [256, 16, 4]}
# 0.833668 (0.006808) with: {'model__hidden_layers': [256, 16, 32]}
# 0.834579 (0.004456) with: {'model__hidden_layers': [256, 16, 64]}
# 0.837129 (0.006181) with: {'model__hidden_layers': [256, 16, 128]}
# 0.833669 (0.006975) with: {'model__hidden_layers': [256, 16, 256]}
# 0.835854 (0.007665) with: {'model__hidden_layers': [256, 16, 512]}
# 0.835125 (0.004882) with: {'model__hidden_layers': [256, 32, 4]}
# 0.837311 (0.007207) with: {'model__hidden_layers': [256, 32, 16]}
# 0.835126 (0.007984) with: {'model__hidden_layers': [256, 32, 64]}
# 0.833669 (0.008375) with: {'model__hidden_layers': [256, 32, 128]}
# 0.835127 (0.010726) with: {'model__hidden_layers': [256, 32, 256]}
# 0.835308 (0.007204) with: {'model__hidden_layers': [256, 32, 512]}
# 0.838223 (0.009263) with: {'model__hidden_layers': [256, 64, 4]}
# 0.834943 (0.005404) with: {'model__hidden_layers': [256, 64, 16]}
# 0.836220 (0.009810) with: {'model__hidden_layers': [256, 64, 32]}
# 0.838040 (0.007849) with: {'model__hidden_layers': [256, 64, 128]}
# 0.832029 (0.010689) with: {'model__hidden_layers': [256, 64, 256]}
# 0.831482 (0.007979) with: {'model__hidden_layers': [256, 64, 512]}
# 0.835855 (0.008376) with: {'model__hidden_layers': [256, 128, 4]}
# 0.833122 (0.009600) with: {'model__hidden_layers': [256, 128, 16]}
# 0.833304 (0.005009) with: {'model__hidden_layers': [256, 128, 32]}
# 0.834033 (0.007461) with: {'model__hidden_layers': [256, 128, 64]}
# 0.836584 (0.007421) with: {'model__hidden_layers': [256, 128, 256]}
# 0.838223 (0.008933) with: {'model__hidden_layers': [256, 128, 512]}
# 0.835126 (0.007357) with: {'model__hidden_layers': [256, 512, 4]}
# 0.834215 (0.007831) with: {'model__hidden_layers': [256, 512, 16]}
# 0.835855 (0.005098) with: {'model__hidden_layers': [256, 512, 32]}
# 0.833486 (0.002813) with: {'model__hidden_layers': [256, 512, 64]}
# 0.835673 (0.007905) with: {'model__hidden_layers': [256, 512, 128]}
# 0.836219 (0.007507) with: {'model__hidden_layers': [256, 512, 256]}
# 0.835126 (0.005966) with: {'model__hidden_layers': [512, 4, 16]}
# 0.836219 (0.006436) with: {'model__hidden_layers': [512, 4, 32]}
# 0.833851 (0.008148) with: {'model__hidden_layers': [512, 4, 64]}
# 0.833668 (0.003362) with: {'model__hidden_layers': [512, 4, 128]}
# 0.835854 (0.005064) with: {'model__hidden_layers': [512, 4, 256]}
# 0.834944 (0.008580) with: {'model__hidden_layers': [512, 4, 512]}
# 0.832029 (0.007402) with: {'model__hidden_layers': [512, 16, 4]}
# 0.833485 (0.005085) with: {'model__hidden_layers': [512, 16, 32]}
# 0.837494 (0.004250) with: {'model__hidden_layers': [512, 16, 64]}
# 0.834761 (0.007665) with: {'model__hidden_layers': [512, 16, 128]}
# 0.833851 (0.007862) with: {'model__hidden_layers': [512, 16, 256]}
# 0.834214 (0.003009) with: {'model__hidden_layers': [512, 16, 512]}
# 0.832940 (0.006382) with: {'model__hidden_layers': [512, 32, 4]}
# 0.837130 (0.006212) with: {'model__hidden_layers': [512, 32, 16]}
# 0.830570 (0.008031) with: {'model__hidden_layers': [512, 32, 64]}
# 0.838587 (0.008748) with: {'model__hidden_layers': [512, 32, 128]}
# 0.837858 (0.006296) with: {'model__hidden_layers': [512, 32, 256]}
# 0.835126 (0.006803) with: {'model__hidden_layers': [512, 32, 512]}
# 0.834579 (0.005202) with: {'model__hidden_layers': [512, 64, 4]}
# 0.831300 (0.005918) with: {'model__hidden_layers': [512, 64, 16]}
# 0.834579 (0.007499) with: {'model__hidden_layers': [512, 64, 32]}
# 0.836583 (0.003534) with: {'model__hidden_layers': [512, 64, 128]}
# 0.837859 (0.008326) with: {'model__hidden_layers': [512, 64, 256]}
# 0.836220 (0.009225) with: {'model__hidden_layers': [512, 64, 512]}
# 0.832939 (0.006062) with: {'model__hidden_layers': [512, 128, 4]}
# 0.835855 (0.004433) with: {'model__hidden_layers': [512, 128, 16]}
# 0.833851 (0.006704) with: {'model__hidden_layers': [512, 128, 32]}
# 0.833305 (0.008303) with: {'model__hidden_layers': [512, 128, 64]}
# 0.833485 (0.002241) with: {'model__hidden_layers': [512, 128, 256]}
# 0.834762 (0.008905) with: {'model__hidden_layers': [512, 128, 512]}
# 0.834943 (0.007411) with: {'model__hidden_layers': [512, 256, 4]}
# 0.834944 (0.008659) with: {'model__hidden_layers': [512, 256, 16]}
# 0.837495 (0.006463) with: {'model__hidden_layers': [512, 256, 32]}
# 0.835673 (0.008511) with: {'model__hidden_layers': [512, 256, 64]}
# 0.835490 (0.006551) with: {'model__hidden_layers': [512, 256, 128]}
# 0.838223 (0.008581) with: {'model__hidden_layers': [512, 256, 512]}

# %%
# Use scikit-learn to grid search the number of neurons & Hidden layers
# Function to create model, required for KerasClassifier
def create_model(hidden_layers):
 # create model
 model = Sequential()
    
 model.add(layers.InputLayer(input_shape=(10))) #10 input columns

 for i, neurons in enumerate(hidden_layers):
            model.add(layers.Dense(neurons, activation="relu"))
        
 model.add(layers.Dense(1, activation='sigmoid'))
           
 # Compile model
 model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
 return model

# create model
model = KerasClassifier(model=create_model, epochs=60, verbose=0)
# define the grid search parameters
hidden_layers = []
neurons1 = [128, 256, 512]
neurons2 = [16, 32, 64]
neurons3 = [16, 32, 64]
neurons4 = [64, 128, 256, 512]

for i in (neurons1):
    for j in (neurons2):
        for k in (neurons3):
            for l in (neurons4):
                if (i != j & j!= k & k!=l):
                    hidden_layers.append([i, j, k, l])

param_grid = dict(model__hidden_layers=hidden_layers)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X_train, Y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.839498 using {'model__hidden_layers': [256, 64, 16, 64]}
# 0.833121 (0.009187) with: {'model__hidden_layers': [128, 16, 32, 64]}
# 0.832029 (0.005097) with: {'model__hidden_layers': [128, 16, 32, 128]}
# 0.830571 (0.007295) with: {'model__hidden_layers': [128, 16, 32, 256]}
# 0.833487 (0.009924) with: {'model__hidden_layers': [128, 16, 32, 512]}
# 0.835854 (0.004101) with: {'model__hidden_layers': [128, 16, 64, 128]}
# 0.833667 (0.006470) with: {'model__hidden_layers': [128, 16, 64, 256]}
# 0.829296 (0.004539) with: {'model__hidden_layers': [128, 16, 64, 512]}
# 0.830024 (0.000855) with: {'model__hidden_layers': [128, 32, 16, 64]}
# 0.832756 (0.005594) with: {'model__hidden_layers': [128, 32, 16, 128]}
# 0.838405 (0.008268) with: {'model__hidden_layers': [128, 32, 16, 256]}
# 0.830025 (0.004049) with: {'model__hidden_layers': [128, 32, 16, 512]}
# 0.833486 (0.006694) with: {'model__hidden_layers': [128, 32, 64, 128]}
# 0.828931 (0.007722) with: {'model__hidden_layers': [128, 32, 64, 256]}
# 0.836584 (0.006705) with: {'model__hidden_layers': [128, 32, 64, 512]}
# 0.831482 (0.005178) with: {'model__hidden_layers': [128, 64, 16, 64]}
# 0.831482 (0.002694) with: {'model__hidden_layers': [128, 64, 16, 128]}
# 0.834943 (0.007325) with: {'model__hidden_layers': [128, 64, 16, 256]}
# 0.831847 (0.008233) with: {'model__hidden_layers': [128, 64, 16, 512]}
# 0.834943 (0.003070) with: {'model__hidden_layers': [128, 64, 32, 64]}
# 0.832211 (0.008250) with: {'model__hidden_layers': [128, 64, 32, 128]}
# 0.834033 (0.004897) with: {'model__hidden_layers': [128, 64, 32, 256]}
# 0.833487 (0.009164) with: {'model__hidden_layers': [128, 64, 32, 512]}
# 0.830934 (0.008728) with: {'model__hidden_layers': [256, 16, 32, 64]}
# 0.831846 (0.005553) with: {'model__hidden_layers': [256, 16, 32, 128]}
# 0.833851 (0.005973) with: {'model__hidden_layers': [256, 16, 32, 256]}
# 0.832211 (0.009253) with: {'model__hidden_layers': [256, 16, 32, 512]}
# 0.834214 (0.007106) with: {'model__hidden_layers': [256, 16, 64, 128]}
# 0.832392 (0.006271) with: {'model__hidden_layers': [256, 16, 64, 256]}
# 0.834032 (0.008658) with: {'model__hidden_layers': [256, 16, 64, 512]}
# 0.828567 (0.003336) with: {'model__hidden_layers': [256, 32, 16, 64]}
# 0.831481 (0.006514) with: {'model__hidden_layers': [256, 32, 16, 128]}
# 0.832757 (0.010705) with: {'model__hidden_layers': [256, 32, 16, 256]}
# 0.833121 (0.002184) with: {'model__hidden_layers': [256, 32, 16, 512]}
# 0.834215 (0.007208) with: {'model__hidden_layers': [256, 32, 64, 128]}
# 0.831483 (0.005852) with: {'model__hidden_layers': [256, 32, 64, 256]}
# 0.831663 (0.005354) with: {'model__hidden_layers': [256, 32, 64, 512]}
# 0.839498 (0.006732) with: {'model__hidden_layers': [256, 64, 16, 64]}
# 0.832758 (0.007755) with: {'model__hidden_layers': [256, 64, 16, 128]}
# 0.830935 (0.009010) with: {'model__hidden_layers': [256, 64, 16, 256]}
# 0.830389 (0.007203) with: {'model__hidden_layers': [256, 64, 16, 512]}
# 0.833851 (0.010524) with: {'model__hidden_layers': [256, 64, 32, 64]}
# 0.834397 (0.006180) with: {'model__hidden_layers': [256, 64, 32, 128]}
# 0.831299 (0.003762) with: {'model__hidden_layers': [256, 64, 32, 256]}
# 0.830389 (0.005307) with: {'model__hidden_layers': [256, 64, 32, 512]}
# 0.832575 (0.004890) with: {'model__hidden_layers': [512, 16, 32, 64]}
# 0.827291 (0.007295) with: {'model__hidden_layers': [512, 16, 32, 128]}
# 0.834943 (0.006951) with: {'model__hidden_layers': [512, 16, 32, 256]}
# 0.829296 (0.007830) with: {'model__hidden_layers': [512, 16, 32, 512]}
# 0.837129 (0.003622) with: {'model__hidden_layers': [512, 16, 64, 128]}
# 0.831481 (0.002555) with: {'model__hidden_layers': [512, 16, 64, 256]}
# 0.831481 (0.004632) with: {'model__hidden_layers': [512, 16, 64, 512]}
# 0.832209 (0.007442) with: {'model__hidden_layers': [512, 32, 16, 64]}
# 0.831664 (0.001920) with: {'model__hidden_layers': [512, 32, 16, 128]}
# 0.830755 (0.013027) with: {'model__hidden_layers': [512, 32, 16, 256]}
# 0.827657 (0.008420) with: {'model__hidden_layers': [512, 32, 16, 512]}
# 0.829296 (0.006073) with: {'model__hidden_layers': [512, 32, 64, 128]}
# 0.834762 (0.006654) with: {'model__hidden_layers': [512, 32, 64, 256]}
# 0.828566 (0.006765) with: {'model__hidden_layers': [512, 32, 64, 512]}
# 0.830389 (0.005722) with: {'model__hidden_layers': [512, 64, 16, 64]}
# 0.821826 (0.008777) with: {'model__hidden_layers': [512, 64, 16, 128]}
# 0.833851 (0.008580) with: {'model__hidden_layers': [512, 64, 16, 256]}
# 0.830752 (0.004574) with: {'model__hidden_layers': [512, 64, 16, 512]}
# 0.836401 (0.005577) with: {'model__hidden_layers': [512, 64, 32, 64]}
# 0.833850 (0.005052) with: {'model__hidden_layers': [512, 64, 32, 128]}
# 0.836401 (0.006437) with: {'model__hidden_layers': [512, 64, 32, 256]}
# 0.832939 (0.005444) with: {'model__hidden_layers': [512, 64, 32, 512]}

# %%
# Use scikit-learn to grid search the number of neurons & Hidden layers
# Function to create model, required for KerasClassifier
def create_model(hidden_layers):
 # create model
 model = Sequential()
    
 model.add(layers.InputLayer(input_shape=(10))) #10 input columns

 for i, neurons in enumerate(hidden_layers):
            model.add(layers.Dense(neurons, activation="relu"))
        
 model.add(layers.Dense(1, activation='sigmoid'))
           
 # Compile model
 model.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
 return model

# create model
model = KerasClassifier(model=create_model, epochs=60, verbose=0)
# define the grid search parameters
hidden_layers = []
neurons1 = [128, 256, 512]
neurons2 = [16, 32, 64]
neurons3 = [16, 32, 64]
neurons4 = [16, 32, 64]
neurons5 = [32, 64, 128, 256, 512]

for i in (neurons1):
    for j in (neurons2):
        for k in (neurons3):
            for l in (neurons4):
                for m in (neurons5):
                    if (i != j & j!= k & k!=l & l!=m):
                        hidden_layers.append([i, j, k, l, m])

param_grid = dict(model__hidden_layers=hidden_layers)
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X_train, Y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))
# Out:
# Best: 0.839315 using {'model__hidden_layers': [128, 32, 64, 32, 64]}
# 0.834942 (0.003607) with: {'model__hidden_layers': [128, 16, 32, 16, 32]}
# 0.828932 (0.010838) with: {'model__hidden_layers': [128, 16, 32, 16, 64]}
# 0.829114 (0.002995) with: {'model__hidden_layers': [128, 16, 32, 16, 128]}
# 0.833304 (0.007478) with: {'model__hidden_layers': [128, 16, 32, 16, 256]}
# 0.829659 (0.008308) with: {'model__hidden_layers': [128, 16, 32, 16, 512]}
# 0.829296 (0.006057) with: {'model__hidden_layers': [128, 16, 32, 64, 32]}
# 0.829659 (0.003824) with: {'model__hidden_layers': [128, 16, 32, 64, 128]}
# 0.827473 (0.002039) with: {'model__hidden_layers': [128, 16, 32, 64, 256]}
# 0.831847 (0.005724) with: {'model__hidden_layers': [128, 16, 32, 64, 512]}
# 0.835308 (0.005370) with: {'model__hidden_layers': [128, 16, 64, 16, 32]}
# 0.827837 (0.001196) with: {'model__hidden_layers': [128, 16, 64, 16, 64]}
# 0.833122 (0.011066) with: {'model__hidden_layers': [128, 16, 64, 16, 128]}
# 0.837129 (0.003528) with: {'model__hidden_layers': [128, 16, 64, 16, 256]}
# 0.827109 (0.004294) with: {'model__hidden_layers': [128, 16, 64, 16, 512]}
# 0.828201 (0.007068) with: {'model__hidden_layers': [128, 16, 64, 32, 64]}
# 0.826197 (0.006205) with: {'model__hidden_layers': [128, 16, 64, 32, 128]}
# 0.826197 (0.003854) with: {'model__hidden_layers': [128, 16, 64, 32, 256]}
# 0.829295 (0.010611) with: {'model__hidden_layers': [128, 16, 64, 32, 512]}
# 0.831482 (0.006223) with: {'model__hidden_layers': [128, 32, 16, 32, 64]}
# 0.825468 (0.005652) with: {'model__hidden_layers': [128, 32, 16, 32, 128]}
# 0.823282 (0.007905) with: {'model__hidden_layers': [128, 32, 16, 32, 256]}
# 0.828750 (0.007401) with: {'model__hidden_layers': [128, 32, 16, 32, 512]}
# 0.830389 (0.003767) with: {'model__hidden_layers': [128, 32, 16, 64, 32]}
# 0.831300 (0.003311) with: {'model__hidden_layers': [128, 32, 16, 64, 128]}
# 0.827656 (0.003362) with: {'model__hidden_layers': [128, 32, 16, 64, 256]}
# 0.822916 (0.010865) with: {'model__hidden_layers': [128, 32, 16, 64, 512]}
# 0.828385 (0.005107) with: {'model__hidden_layers': [128, 32, 64, 16, 32]}
# 0.827292 (0.008869) with: {'model__hidden_layers': [128, 32, 64, 16, 64]}
# 0.826927 (0.012896) with: {'model__hidden_layers': [128, 32, 64, 16, 128]}
# 0.828566 (0.008978) with: {'model__hidden_layers': [128, 32, 64, 16, 256]}
# 0.832392 (0.002686) with: {'model__hidden_layers': [128, 32, 64, 16, 512]}
# 0.839315 (0.004975) with: {'model__hidden_layers': [128, 32, 64, 32, 64]}
# 0.827655 (0.002280) with: {'model__hidden_layers': [128, 32, 64, 32, 128]}
# 0.827111 (0.009999) with: {'model__hidden_layers': [128, 32, 64, 32, 256]}
# 0.833484 (0.004063) with: {'model__hidden_layers': [128, 32, 64, 32, 512]}
# 0.831117 (0.009955) with: {'model__hidden_layers': [128, 64, 16, 32, 64]}
# 0.826562 (0.006365) with: {'model__hidden_layers': [128, 64, 16, 32, 128]}
# 0.825288 (0.006661) with: {'model__hidden_layers': [128, 64, 16, 32, 256]}
# 0.835490 (0.005118) with: {'model__hidden_layers': [128, 64, 16, 32, 512]}
# 0.825104 (0.002391) with: {'model__hidden_layers': [128, 64, 16, 64, 32]}
# 0.822553 (0.003761) with: {'model__hidden_layers': [128, 64, 16, 64, 128]}
# 0.829113 (0.003204) with: {'model__hidden_layers': [128, 64, 16, 64, 256]}
# 0.828749 (0.003185) with: {'model__hidden_layers': [128, 64, 16, 64, 512]}
# 0.829112 (0.005836) with: {'model__hidden_layers': [128, 64, 32, 16, 32]}
# 0.829113 (0.004751) with: {'model__hidden_layers': [128, 64, 32, 16, 64]}
# 0.825651 (0.005142) with: {'model__hidden_layers': [128, 64, 32, 16, 128]}
# 0.826926 (0.003613) with: {'model__hidden_layers': [128, 64, 32, 16, 256]}
# 0.831846 (0.006614) with: {'model__hidden_layers': [128, 64, 32, 16, 512]}
# 0.831482 (0.006653) with: {'model__hidden_layers': [128, 64, 32, 64, 32]}
# 0.824557 (0.006693) with: {'model__hidden_layers': [128, 64, 32, 64, 128]}
# 0.832576 (0.007617) with: {'model__hidden_layers': [128, 64, 32, 64, 256]}
# 0.827292 (0.007325) with: {'model__hidden_layers': [128, 64, 32, 64, 512]}
# 0.823829 (0.001810) with: {'model__hidden_layers': [256, 16, 32, 16, 32]}
# 0.831117 (0.005594) with: {'model__hidden_layers': [256, 16, 32, 16, 64]}
# 0.831846 (0.002853) with: {'model__hidden_layers': [256, 16, 32, 16, 128]}
# 0.827108 (0.004064) with: {'model__hidden_layers': [256, 16, 32, 16, 256]}
# 0.832210 (0.003808) with: {'model__hidden_layers': [256, 16, 32, 16, 512]}
# 0.822920 (0.019973) with: {'model__hidden_layers': [256, 16, 32, 64, 32]}
# 0.831300 (0.009830) with: {'model__hidden_layers': [256, 16, 32, 64, 128]}
# 0.830389 (0.002206) with: {'model__hidden_layers': [256, 16, 32, 64, 256]}
# 0.831845 (0.003395) with: {'model__hidden_layers': [256, 16, 32, 64, 512]}
# 0.831298 (0.004805) with: {'model__hidden_layers': [256, 16, 64, 16, 32]}
# 0.816903 (0.014962) with: {'model__hidden_layers': [256, 16, 64, 16, 64]}
# 0.827657 (0.005899) with: {'model__hidden_layers': [256, 16, 64, 16, 128]}
# 0.831482 (0.006141) with: {'model__hidden_layers': [256, 16, 64, 16, 256]}
# 0.827656 (0.007686) with: {'model__hidden_layers': [256, 16, 64, 16, 512]}
# 0.825834 (0.003203) with: {'model__hidden_layers': [256, 16, 64, 32, 64]}
# 0.832029 (0.006882) with: {'model__hidden_layers': [256, 16, 64, 32, 128]}
# 0.832029 (0.007965) with: {'model__hidden_layers': [256, 16, 64, 32, 256]}
# 0.830388 (0.000723) with: {'model__hidden_layers': [256, 16, 64, 32, 512]}
# 0.833851 (0.007152) with: {'model__hidden_layers': [256, 32, 16, 32, 64]}
# 0.826015 (0.010318) with: {'model__hidden_layers': [256, 32, 16, 32, 128]}
# 0.828748 (0.004294) with: {'model__hidden_layers': [256, 32, 16, 32, 256]}
# 0.829478 (0.004694) with: {'model__hidden_layers': [256, 32, 16, 32, 512]}
# 0.823828 (0.007596) with: {'model__hidden_layers': [256, 32, 16, 64, 32]}
# 0.830388 (0.008414) with: {'model__hidden_layers': [256, 32, 16, 64, 128]}
# 0.827108 (0.006943) with: {'model__hidden_layers': [256, 32, 16, 64, 256]}
# 0.826562 (0.002885) with: {'model__hidden_layers': [256, 32, 16, 64, 512]}
# 0.833120 (0.004420) with: {'model__hidden_layers': [256, 32, 64, 16, 32]}
# 0.827474 (0.001815) with: {'model__hidden_layers': [256, 32, 64, 16, 64]}
# 0.831300 (0.005581) with: {'model__hidden_layers': [256, 32, 64, 16, 128]}
# 0.824376 (0.006084) with: {'model__hidden_layers': [256, 32, 64, 16, 256]}
# 0.835672 (0.005139) with: {'model__hidden_layers': [256, 32, 64, 16, 512]}
# 0.829296 (0.004431) with: {'model__hidden_layers': [256, 32, 64, 32, 64]}
# 0.828202 (0.002414) with: {'model__hidden_layers': [256, 32, 64, 32, 128]}
# 0.826379 (0.004534) with: {'model__hidden_layers': [256, 32, 64, 32, 256]}
# 0.830024 (0.007370) with: {'model__hidden_layers': [256, 32, 64, 32, 512]}
# 0.835307 (0.002051) with: {'model__hidden_layers': [256, 64, 16, 32, 64]}
# 0.830387 (0.008276) with: {'model__hidden_layers': [256, 64, 16, 32, 128]}
# 0.829660 (0.007668) with: {'model__hidden_layers': [256, 64, 16, 32, 256]}
# 0.828202 (0.003454) with: {'model__hidden_layers': [256, 64, 16, 32, 512]}
# 0.825836 (0.012288) with: {'model__hidden_layers': [256, 64, 16, 64, 32]}
# 0.818729 (0.002811) with: {'model__hidden_layers': [256, 64, 16, 64, 128]}
# 0.829296 (0.008018) with: {'model__hidden_layers': [256, 64, 16, 64, 256]}
# 0.826381 (0.005562) with: {'model__hidden_layers': [256, 64, 16, 64, 512]}
# 0.824193 (0.009190) with: {'model__hidden_layers': [256, 64, 32, 16, 32]}
# 0.831298 (0.005401) with: {'model__hidden_layers': [256, 64, 32, 16, 64]}
# 0.830206 (0.001528) with: {'model__hidden_layers': [256, 64, 32, 16, 128]}
# 0.825106 (0.009429) with: {'model__hidden_layers': [256, 64, 32, 16, 256]}
# 0.833486 (0.007068) with: {'model__hidden_layers': [256, 64, 32, 16, 512]}
# 0.829841 (0.004024) with: {'model__hidden_layers': [256, 64, 32, 64, 32]}
# 0.826927 (0.002157) with: {'model__hidden_layers': [256, 64, 32, 64, 128]}
# 0.827837 (0.003556) with: {'model__hidden_layers': [256, 64, 32, 64, 256]}
# 0.829112 (0.004675) with: {'model__hidden_layers': [256, 64, 32, 64, 512]}
# 0.826197 (0.002270) with: {'model__hidden_layers': [512, 16, 32, 16, 32]}
# 0.821277 (0.012177) with: {'model__hidden_layers': [512, 16, 32, 16, 64]}
# 0.821462 (0.007331) with: {'model__hidden_layers': [512, 16, 32, 16, 128]}
# 0.831117 (0.008033) with: {'model__hidden_layers': [512, 16, 32, 16, 256]}
# 0.831118 (0.007348) with: {'model__hidden_layers': [512, 16, 32, 16, 512]}
# 0.827473 (0.007126) with: {'model__hidden_layers': [512, 16, 32, 64, 32]}
# 0.826927 (0.005201) with: {'model__hidden_layers': [512, 16, 32, 64, 128]}
# 0.826197 (0.002717) with: {'model__hidden_layers': [512, 16, 32, 64, 256]}
# 0.812348 (0.016595) with: {'model__hidden_layers': [512, 16, 32, 64, 512]}
# 0.826378 (0.008817) with: {'model__hidden_layers': [512, 16, 64, 16, 32]}
# 0.829477 (0.002696) with: {'model__hidden_layers': [512, 16, 64, 16, 64]}
# 0.824012 (0.002932) with: {'model__hidden_layers': [512, 16, 64, 16, 128]}
# 0.829660 (0.009421) with: {'model__hidden_layers': [512, 16, 64, 16, 256]}
# 0.833487 (0.009394) with: {'model__hidden_layers': [512, 16, 64, 16, 512]}
# 0.828749 (0.009187) with: {'model__hidden_layers': [512, 16, 64, 32, 64]}
# 0.830388 (0.006807) with: {'model__hidden_layers': [512, 16, 64, 32, 128]}
# 0.834215 (0.004874) with: {'model__hidden_layers': [512, 16, 64, 32, 256]}
# 0.829296 (0.002650) with: {'model__hidden_layers': [512, 16, 64, 32, 512]}
# 0.822007 (0.005086) with: {'model__hidden_layers': [512, 32, 16, 32, 64]}
# 0.828931 (0.008170) with: {'model__hidden_layers': [512, 32, 16, 32, 128]}
# 0.811438 (0.013897) with: {'model__hidden_layers': [512, 32, 16, 32, 256]}
# 0.829477 (0.003571) with: {'model__hidden_layers': [512, 32, 16, 32, 512]}
# 0.824741 (0.008528) with: {'model__hidden_layers': [512, 32, 16, 64, 32]}
# 0.820005 (0.013808) with: {'model__hidden_layers': [512, 32, 16, 64, 128]}
# 0.822916 (0.009412) with: {'model__hidden_layers': [512, 32, 16, 64, 256]}
# 0.829841 (0.004472) with: {'model__hidden_layers': [512, 32, 16, 64, 512]}
# 0.824741 (0.010629) with: {'model__hidden_layers': [512, 32, 64, 16, 32]}
# 0.829842 (0.007322) with: {'model__hidden_layers': [512, 32, 64, 16, 64]}
# 0.817272 (0.020171) with: {'model__hidden_layers': [512, 32, 64, 16, 128]}
# 0.826744 (0.003570) with: {'model__hidden_layers': [512, 32, 64, 16, 256]}
# 0.825835 (0.004470) with: {'model__hidden_layers': [512, 32, 64, 16, 512]}
# 0.818548 (0.010875) with: {'model__hidden_layers': [512, 32, 64, 32, 64]}
# 0.825834 (0.009601) with: {'model__hidden_layers': [512, 32, 64, 32, 128]}
# 0.832394 (0.007766) with: {'model__hidden_layers': [512, 32, 64, 32, 256]}
# 0.826198 (0.002478) with: {'model__hidden_layers': [512, 32, 64, 32, 512]}
# 0.817270 (0.004767) with: {'model__hidden_layers': [512, 64, 16, 32, 64]}
# 0.834761 (0.001846) with: {'model__hidden_layers': [512, 64, 16, 32, 128]}
# 0.826199 (0.008530) with: {'model__hidden_layers': [512, 64, 16, 32, 256]}
# 0.831117 (0.006648) with: {'model__hidden_layers': [512, 64, 16, 32, 512]}
# 0.828568 (0.007944) with: {'model__hidden_layers': [512, 64, 16, 64, 32]}
# 0.823283 (0.009617) with: {'model__hidden_layers': [512, 64, 16, 64, 128]}
# 0.816721 (0.015248) with: {'model__hidden_layers': [512, 64, 16, 64, 256]}
# 0.827838 (0.011178) with: {'model__hidden_layers': [512, 64, 16, 64, 512]}
# 0.828931 (0.012493) with: {'model__hidden_layers': [512, 64, 32, 16, 32]}
# 0.827291 (0.007185) with: {'model__hidden_layers': [512, 64, 32, 16, 64]}
# 0.826199 (0.009430) with: {'model__hidden_layers': [512, 64, 32, 16, 128]}
# 0.830206 (0.001673) with: {'model__hidden_layers': [512, 64, 32, 16, 256]}
# 0.828019 (0.007252) with: {'model__hidden_layers': [512, 64, 32, 16, 512]}
# 0.824195 (0.004174) with: {'model__hidden_layers': [512, 64, 32, 64, 32]}
# 0.827836 (0.008305) with: {'model__hidden_layers': [512, 64, 32, 64, 128]}
# 0.826196 (0.010144) with: {'model__hidden_layers': [512, 64, 32, 64, 256]}
# 0.818910 (0.013389) with: {'model__hidden_layers': [512, 64, 32, 64, 512]}
